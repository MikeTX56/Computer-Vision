# %%
# Install OpenCV in this notebook kernel
# %pip -q install opencv-python

# %%
import os
import cv2
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# #### 1. Reading images using OpenCV

# %%
# Alternative: use Jupyter file browser or widget upload (non-Colab)
from pathlib import Path
try:
    import ipywidgets as widgets
    from IPython.display import display
    
    uploader = widgets.FileUpload(accept='image/*', multiple=False)
    display(uploader)
    print('Upload a file above, then run the next cell to read it.')
except Exception as e:
    print('ipywidgets not available. Put the image in the working folder and set image_path manually.')
    # Example: image_path = 'my_image.jpg'
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')
# Upload a file above, then run the next cell to read it.

# %%
# Display the image
Image(filename=image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1274205599.py in <cell line: 0>()
#       1 # Display the image
# ----> 2 Image(filename=image_path)
#
# NameError: name 'image_path' is not defined
